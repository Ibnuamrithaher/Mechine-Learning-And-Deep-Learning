# %% [markdown]
# <a href="https://colab.research.google.com/github/Ibnuamrithaher/Mechine-Learning-And-Deep-Learning/blob/main/SVM/part1%20-%20Support%20Vector%20Mechine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install luwiji
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 MB 19.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for luwiji: filename=luwiji-1.2.3-py2.py3-none-any.whl size=41032443 sha256=b681c2793012df06cce54d85f40389e27a0a100d4dd39a3a62923ec084998195
#   Stored in directory: /root/.cache/pip/wheels/49/64/e5/da119dce51f27490590d60c3df8932db315ab0454251e18955
# Successfully built luwiji
# ...

# %%
from luwiji.svm import illustration, demo

# %% [markdown]
# ## **Problem 1**

# %%
demo.problem(1)

# %%
illustration.choose_one

# %% [markdown]
# ## **Solusi: Mencari margin paling lebar**
# SVM dulunya dikenal sebagai maximum margin classifier. Ternyata alternatif untuk memperoleh maximum margin adalah dengan mencari support vector (data yang dilingkari). Itulah mengapa nama algoritma ini juga disebut sebagai Support Vector Machine, yakni mesin pencari support vector.

# %%
illustration.maximum_margin

# %% [markdown]
# ##  **C - Penalty Parameter**
#
# Semakin besar C => semakin besar penalty terhadap kesalahan => lebih sensitif
#
#
# Semakin kecil C => semakin toleran terhadap kesalahan => lebih smooth

# %%
demo.C(1)
# Out:
# interactive(children=(FloatLogSlider(value=10.0, description='C', max=1.0, min=-2.0, step=0.25), Output()), _d…

# %% [markdown]
# ## **Problem 2: Ternyata toleran saja tidak cukup**

# %%
demo.problem(2)

# %%
demo.C(2)
# Out:
# interactive(children=(FloatLogSlider(value=10.0, description='C', max=1.0, min=-2.0, step=0.25), Output()), _d…

# %% [markdown]
# ## **Solusi: kita butuh Perspektif baru -> Kernel Trick**
#
# Ide nya adalah kita melakukan transformasi data-data kita ke dimensi lain
#
# Misalkan kita transformasi menggunakan persamaan distribusi Gaussian
#
# Maka kita menyebutnya sebagai SVM menggunakan kernel Gaussian
#
# Kernel Gaussian merupakan salah satu dari keluarga RBF (Radial Basis Function)

# %%
demo.rbf()
# Out:
# interactive(children=(IntSlider(value=90, description='elevation', max=90, step=15), FloatSlider(value=0.0, de…

# %%
demo.kernel(2)
# Out:
# interactive(children=(ToggleButtons(description='Kernel', options=('linear', 'rbf'), value='linear'), FloatLog…

# %% [markdown]
# ## **Problem 3: Scale**

# %%
demo.problem(3)

# %%
demo.kernel(3)
# Out:
# interactive(children=(ToggleButtons(description='Kernel', options=('linear', 'rbf'), value='linear'), FloatLog…

# %% [markdown]
# ## **Solusi: big picture vs detail oriented ->  kernel coefficient**
#
# Semakin besar y => semakin detail oriented => lebih sensitif
#
# Semakin kecil y => semakin melihat big picture => lebih smooth

# %%
demo.gamma()
# Out:
# interactive(children=(FloatLogSlider(value=31.622776601683793, description='gamma', max=1.5, min=-1.5, step=0.…

# %%
demo.svm()
# Out:
# interactive(children=(ToggleButtons(description='Problem', options=(1, 2, 3), value=1), Output()), _dom_classe…
