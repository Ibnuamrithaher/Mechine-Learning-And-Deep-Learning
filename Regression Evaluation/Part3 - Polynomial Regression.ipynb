# %% [markdown]
# <a href="https://colab.research.google.com/github/Ibnuamrithaher/Mechine-Learning-And-Deep-Learning/blob/main/Regression%20Evaluation/Part3%20-%20Polynomial%20Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install luwiji
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 MB 10.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.8/107.8 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 32.5 MB/s eta 0:00:00
# ...
#   Created wheel for luwiji: filename=luwiji-1.2.3-py2.py3-none-any.whl size=41032443 sha256=f9fb8716cfcd3c28e6a425e69e2efbe9013d6244961d21e4f0ea9f627fd46888
#   Stored in directory: /root/.cache/pip/wheels/25/9b/68/61b665f8682276ffbc7fa54bae3ccc541be2ed103979770b9b
# ...
#   Created wheel for jcopml: filename=jcopml-1.2.7-py2.py3-none-any.whl size=45916 sha256=30e045ae87711cc3b53c049f0d8ae6ec8b8dc22b99958ed68b2eeb045b0081a3
#   Stored in directory: /root/.cache/pip/wheels/77/a7/60/c75983f4da5b630422325c5048591b6ee9e2ce123bf2b7b357
# Successfully built luwiji jcopml
# ...

# %%
from luwiji.poly_regression import illustration, demo

# %%
demo.data()

# %% [markdown]
# # Polynomial Regression

# %%
illustration.polynomial_regression

# %% [markdown]
# ![download (1).png](data:image/png;base64,...)

# %%
demo.polynomial_regression()
# Out:
# interactive(children=(ToggleButtons(description='Model', options=('Poly(1)', 'Poly(2)', 'Poly(3)', 'Poly(10)',…

# %%
demo.nonlinear()
# Out:
# interactive(children=(ToggleButtons(description='Model', options=('Poly(1)', 'Poly(2)', 'Poly(3)', 'Poly(10)',…

# %% [markdown]
# ## Scikit-learn code
#
# model = Pipeline([
#     ("poly", PolynomialFeatures(5)),
#     ("lr", LinearRegression())
# ])
# model.fit(X_train, y_train)
