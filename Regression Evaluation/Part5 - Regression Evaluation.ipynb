# %% [markdown]
# <a href="https://colab.research.google.com/github/Ibnuamrithaher/Mechine-Learning-And-Deep-Learning/blob/main/Regression%20Evaluation/Part5%20-%20Regression%20Evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install luwiji

# %%
from luwiji.evaluation import illustration, demo
from jcopml.plot import plot_actual_vs_prediction, plot_residual

# %%
X_train, y_train, X_test, y_test, model = demo.get_regression_data()

# %% [markdown]
# ## Method 1: Overlay

# %% [markdown]
# hanya untuk yang maks 2 dimensi karena kita hanya bisa plot 3D

# %%
illustration.overlay_regression

# %% [markdown]
# ## Method 2: Actual vs Prediction Plot

# %%
plot_actual_vs_prediction(X_train, y_train, X_test, y_test, model)

# %% [markdown]
# ## Contoh Underfit

# %%
illustration.avp_underfit

# %% [markdown]
# ## Contoh Overfit

# %%
illustration.avp_overfit

# %% [markdown]
# ## Method 3: Residual Plot

# %%
plot_residual(X_train, y_train, X_test, y_test, model)

# %% [markdown]
# ## Residual Plot Analysis
#
#
# http://docs.statwing.com/interpreting-residual-plots-to-improve-your-regression/#large-axis-header
